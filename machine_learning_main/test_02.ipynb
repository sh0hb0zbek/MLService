# %%
from source_v02 import *

# %%
def machine_learning_main_test():
    args = {
        'model_name':       '',
        'dataset_filepath': '',
        'scaler_type':      'StandardScaler',
        'test_size':        0.3,
        'random_state':     15,
        'shuffle':          True,
        'plot':             True,
        'plot_filename':    '',
        'save_filename':    None,
    }

    # classifier
    dataset_filepath = '../dataset/Social_Network_Ads.csv'  # classification
    args['dataset_filepath'] = dataset_filepath
    for t in MODELS['classifier']:
        for model_name in MODELS['classifier'][t]:
            print('-' * 30)
            print(f'[{t}] {model_name}')
            print('-' * 30)
            args['model_name'] = model_name
            args['plot_filename'] = './plot_images/'+model_name
            machine_learning_main(**args)

    # regression
    dataset_filepath = '../dataset/studentscores.csv'       # regression
    args['dataset_filepath'] = dataset_filepath
    for t in MODELS['regressor']:
        for model_name in MODELS['regressor'][t]:
            print('-' * 30)
            print(f'[{t}] {model_name}')
            print('-' * 30)
            args['model_name'] = model_name
            machine_learning_main(**args)

# %%
machine_learning_main_test()
# Out:
# ------------------------------
# [linear_model] LogisticRegression
# ------------------------------
# [LogisticRegression]
# confusion_matrix: [[74  5]
#  [ 9 32]]
# accuracy_score: 0.8833333333333333
# ------------------------------
# [linear_model] LogisticRegressionCV
# ------------------------------
# [LogisticRegressionCV]
# confusion_matrix: [[74  5]
#  [ 9 32]]
# accuracy_score: 0.8833333333333333
# ------------------------------
# [linear_model] PassiveAggressiveClassifier
# ------------------------------
# [PassiveAggressiveClassifier]
# confusion_matrix: [[55 24]
#  [13 28]]
# accuracy_score: 0.6916666666666667
# ------------------------------
# [linear_model] Perceptron
# ------------------------------
# [Perceptron]
# confusion_matrix: [[71  8]
#  [10 31]]
# accuracy_score: 0.85
# ------------------------------
# [linear_model] RidgeClassifier
# ------------------------------
# [RidgeClassifier]
# confusion_matrix: [[74  5]
#  [10 31]]
# accuracy_score: 0.875
# ------------------------------
# [linear_model] RidgeClassifierCV
# ------------------------------
# [RidgeClassifierCV]
# confusion_matrix: [[74  5]
#  [10 31]]
# accuracy_score: 0.875
# ------------------------------
# [linear_model] SGDClassifier
# ------------------------------
# [SGDClassifier]
# confusion_matrix: [[65 14]
#  [ 7 34]]
# accuracy_score: 0.825
# ------------------------------
# [neighbors] KNeighborsClassifier
# ------------------------------
# [KNeighborsClassifier]
# confusion_matrix: [[73  6]
#  [ 6 35]]
# accuracy_score: 0.9
# ------------------------------
# [neighbors] RadiusNeighborsClassifier
# ------------------------------
# [RadiusNeighborsClassifier]
# confusion_matrix: [[75  4]
#  [ 8 33]]
# accuracy_score: 0.9
# ------------------------------
# [svm] LinearSVC
# ------------------------------
# [LinearSVC]
# confusion_matrix: [[74  5]
#  [ 9 32]]
# accuracy_score: 0.8833333333333333
# ------------------------------
# [svm] NuSVC
# ------------------------------
# [NuSVC]
# confusion_matrix: [[72  7]
#  [ 7 34]]
# accuracy_score: 0.8833333333333333
# ------------------------------
# [svm] SVC
# ------------------------------
# [SVC]
# confusion_matrix: [[72  7]
#  [ 6 35]]
# accuracy_score: 0.8916666666666667
# ------------------------------
# [tree] DecisionTreeClassifier
# ------------------------------
# [DecisionTreeClassifier]
# confusion_matrix: [[71  8]
#  [ 8 33]]
# accuracy_score: 0.8666666666666667
# ------------------------------
# [tree] ExtraTreeClassifier
# ------------------------------
# [ExtraTreeClassifier]
# confusion_matrix: [[68 11]
#  [13 28]]
# accuracy_score: 0.8
# ------------------------------
# [ensemble] AdaBoostClassifier
# ------------------------------
# [AdaBoostClassifier]
# confusion_matrix: [[73  6]
#  [ 7 34]]
# accuracy_score: 0.8916666666666667
# ------------------------------
# [ensemble] BaggingClassifier
# ------------------------------
# [BaggingClassifier]
# confusion_matrix: [[73  6]
#  [10 31]]
# accuracy_score: 0.8666666666666667
# ------------------------------
# [ensemble] ExtraTreesClassifier
# ------------------------------
# [ExtraTreesClassifier]
# confusion_matrix: [[75  4]
#  [ 7 34]]
# accuracy_score: 0.9083333333333333
# ------------------------------
# [ensemble] GradientBoostingClassifier
# ------------------------------
# [GradientBoostingClassifier]
# confusion_matrix: [[74  5]
#  [ 5 36]]
# accuracy_score: 0.9166666666666666
# ------------------------------
# [ensemble] HistGradientBoostingClassifier
# ------------------------------
# [HistGradientBoostingClassifier]
# confusion_matrix: [[72  7]
#  [ 5 36]]
# accuracy_score: 0.9
# ------------------------------
# [ensemble] RandomForestClassifier
# ------------------------------
# [RandomForestClassifier]
# confusion_matrix: [[73  6]
#  [ 4 37]]
# accuracy_score: 0.9166666666666666
# ------------------------------
# [linear_model] ARDRegression
# ------------------------------
# [ARDRegression]
# mean_squared_error: 46.532489071829346
# ------------------------------
# [linear_model] BayesianRidge
# ------------------------------
# [BayesianRidge]
# mean_squared_error: 46.53248907182933
# ------------------------------
# [linear_model] ElasticNet
# ------------------------------
# [ElasticNet]
# mean_squared_error: 87.67652561351986
# ------------------------------
# [linear_model] ElasticNetCV
# ------------------------------
# [ElasticNetCV]
# mean_squared_error: 44.190269531434964
# ------------------------------
# [linear_model] GammaRegressor
# ------------------------------
# [GammaRegressor]
# mean_squared_error: 164.363204085277
# ------------------------------
# [linear_model] HuberRegressor
# ------------------------------
# [HuberRegressor]
# mean_squared_error: 49.51068959827664
# ------------------------------
# [linear_model] Lars
# ------------------------------
# [Lars]
# mean_squared_error: 46.820205032038736
# ------------------------------
# [linear_model] LarsCV
# ------------------------------
# [LarsCV]
# mean_squared_error: 46.820205032038736
# ------------------------------
# [linear_model] Lasso
# ------------------------------
# [Lasso]
# mean_squared_error: 42.95107214185197
# ------------------------------
# [linear_model] LassoCV
# ------------------------------
# [LassoCV]
# mean_squared_error: 46.697860245929974
# ------------------------------
# [linear_model] LassoLars
# ------------------------------
# [LassoLars]
# mean_squared_error: 45.79295822278189
# ------------------------------
# [linear_model] LassoLarsCV
# ------------------------------
# [LassoLarsCV]
# mean_squared_error: 46.820205032038736
# ------------------------------
# [linear_model] LassoLarsIC
# ------------------------------
# [LassoLarsIC]
# mean_squared_error: 46.820205032038736
# ------------------------------
# [linear_model] LinearRegression
# ------------------------------
# [LinearRegression]
# mean_squared_error: 46.82020503203874
# ------------------------------
# [linear_model] OrthogonalMatchingPursuit
# ------------------------------
# [OrthogonalMatchingPursuit]
# mean_squared_error: 46.820205032038736
# ------------------------------
# [linear_model] PassiveAggressiveRegressor
# ------------------------------
# [PassiveAggressiveRegressor]
# mean_squared_error: 66.53971810032539
# ------------------------------
# [linear_model] PoissonRegressor
# ------------------------------
# [PoissonRegressor]
# mean_squared_error: 107.7805679166088
# ------------------------------
# [linear_model] QuantileRegressor
# ------------------------------
# [QuantileRegressor]
# mean_squared_error: 776.1250092237999
# ------------------------------
# [linear_model] RANSACRegressor
# ------------------------------
# [RANSACRegressor]
# mean_squared_error: 46.82020503203874
# ------------------------------
# [linear_model] Ridge
# ------------------------------
# [Ridge]
# mean_squared_error: 42.126763556157854
# ------------------------------
# [linear_model] RidgeCV
# ------------------------------
# [RidgeCV]
# mean_squared_error: 46.12441443274378
# ------------------------------
# [linear_model] SGDRegressor
# ------------------------------
# [SGDRegressor]
# mean_squared_error: 45.3532547288585
# ------------------------------
# [linear_model] TheilSenRegressor
# ------------------------------
# [TheilSenRegressor]
# mean_squared_error: 50.6313853610524
# ------------------------------
# [linear_model] TweedieRegressor
# ------------------------------
# [TweedieRegressor]
# mean_squared_error: 158.80668406197353
# ------------------------------
# [neighbors] KNeighborsRegressor
# ------------------------------
# [KNeighborsRegressor]
# mean_squared_error: 18.749999999999993
# ------------------------------
# [neighbors] RadiusNeighborsRegressor
# ------------------------------
# [RadiusNeighborsRegressor]
# mean_squared_error: 30.383075771630963
# ------------------------------
# [svm] LinearSVR
# ------------------------------
# [LinearSVR]
# mean_squared_error: 2144.875
# ------------------------------
# [svm] NuSVR
# ------------------------------
# [NuSVR]
# mean_squared_error: 520.9993294513888
# ------------------------------
# [svm] SVR
# ------------------------------
# [SVR]
# mean_squared_error: 471.5415800084232
# ------------------------------
# [tree] DecisionTreeRegressor
# ------------------------------
# [DecisionTreeRegressor]
# mean_squared_error: 61.375
# ------------------------------
# [tree] ExtraTreeRegressor
# ------------------------------
# [ExtraTreeRegressor]
# mean_squared_error: 61.375
# ------------------------------
# [ensemble] AdaBoostRegressor
# ------------------------------
# [AdaBoostRegressor]
# mean_squared_error: 47.040895061728406
# ------------------------------
# [ensemble] BaggingRegressor
# ------------------------------
# [BaggingRegressor]
# mean_squared_error: 59.067499999999995
# ------------------------------
# [ensemble] ExtraTreesRegressor
# ------------------------------
# [ExtraTreesRegressor]
# mean_squared_error: 64.63082812500002
# ------------------------------
# [ensemble] GradientBoostingRegressor
# ------------------------------
# [GradientBoostingRegressor]
# mean_squared_error: 60.5748811996271
# ------------------------------
# [ensemble] HistGradientBoostingRegressor
# ------------------------------
# [HistGradientBoostingRegressor]
# mean_squared_error: 617.8049307958477
# ------------------------------
# [ensemble] RandomForestRegressor
# ------------------------------
# [RandomForestRegressor]
# mean_squared_error: 40.56624765625003

# %%
from test_v2 import linear_model_test

# %%
regressor_models = ['ARDRegression', 'BayesianRidge','ElasticNet','ElasticNetCV','GammaRegressor',
                    'HuberRegressor','Lars','LarsCV','Lasso','LassoCV','LassoLars','LassoLarsCV',
                    'LassoLarsIC','LinearRegression','OrthogonalMatchingPursuit',
                    'PassiveAggressiveRegressor','PoissonRegressor','QuantileRegressor',
                    'RANSACRegressor','Ridge','RidgeCV','SGDRegressor','TheilSenRegressor','TweedieRegressor']

classifier_models = ['LogisticRegression','LogisticRegressionCV','PassiveAggressiveClassifier',
                     'Perceptron','RidgeClassifier','RidgeClassifierCV','SGDClassifier']

# %%
dataset_filepath = '../dataset/Social_Network_Ads.csv'
for name in classifier_models:
    linear_model_test(name, dataset_filepath=dataset_filepath)
# Out:
# [LogisticRegression]
# Accuracy:  0.825
# Confusion Matrix:
# Time to fit model: 0:00:00.004842
# -----------------------------------------------------------------
#
# [LogisticRegressionCV]
# Accuracy:  0.825
# Confusion Matrix:
# Time to fit model: 0:00:00.045979
# -----------------------------------------------------------------
#
# [PassiveAggressiveClassifier]
# Accuracy:  0.3416666666666667
# Confusion Matrix:
# Time to fit model: 0:00:00.000460
# -----------------------------------------------------------------
#
# [Perceptron]
# Accuracy:  0.3416666666666667
# Confusion Matrix:
# Time to fit model: 0:00:00.000554
# -----------------------------------------------------------------
#
# [RidgeClassifier]
# Accuracy:  0.875
# Confusion Matrix:
# Time to fit model: 0:00:00.001228
# -----------------------------------------------------------------
#
# [RidgeClassifierCV]
# Accuracy:  0.875
# Confusion Matrix:
# Time to fit model: 0:00:00.001418
# ...
